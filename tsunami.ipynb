# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
tsunami_df = pd.read_csv('waves.csv')

# %%
tsunami_df.columns
# Out:
# Index(['SOURCE_ID', 'WAVE_ID', 'YEAR', 'MONTH', 'DAY', 'REGION_CODE',
#        'COUNTRY', 'STATE/PROVINCE', 'LOCATION', 'LATITUDE', 'LONGITUDE',
#        'DISTANCE_FROM_SOURCE', 'TRAVEL_TIME_HOURS', 'TRAVEL_TIME_MINUTES',
#        'VALIDITY', 'MEASUREMENT_TYPE', 'PERIOD', 'FIRST_MOTION',
#        'MAXIMUM_HEIGHT', 'HORIZONTAL_INUNDATION', 'INJURIES',
#        'INJURY_ESTIMATE', 'FATALITIES', 'FATALITY_ESTIMATE',
#        'DAMAGE_MILLIONS_DOLLARS', 'DAMAGE_ESTIMATE', 'HOUSES_DAMAGED',
#        'HOUSE_DAMAGE_ESTIMATE', 'HOUSES_DESTROYED',
#        'HOUSE_DESTRUCTION_ESTIMATE'],
#       dtype='object')

# %%
tsunami_df = tsunami_df.drop(['INJURY_ESTIMATE','STATE/PROVINCE', 'LOCATION', 'LATITUDE', 'LONGITUDE', 'SOURCE_ID', 'WAVE_ID', 'MONTH', 'DAY', 'REGION_CODE', 'DISTANCE_FROM_SOURCE', 'VALIDITY', 'MEASUREMENT_TYPE', 'PERIOD', 'HORIZONTAL_INUNDATION'], axis=1)

# %%
tsunami_df.sort_values('FATALITIES', ascending=False)
# Out:
#        YEAR           COUNTRY  TRAVEL_TIME_HOURS  TRAVEL_TIME_MINUTES  \
# 699    1737             INDIA                NaN                  NaN
# 14415  2004         INDONESIA                NaN                  NaN
# 2516   1883         INDONESIA                NaN                  NaN
# 14332  2004         SRI LANKA                NaN                  NaN
# 778    1755          PORTUGAL                NaN                  NaN
# 819    1755          PORTUGAL                NaN                  NaN
# 207    1498             JAPAN                NaN                  NaN
# 2809   1896             JAPAN                NaN                  NaN
# 14416  2004             INDIA                NaN                  NaN
# 944    1771             JAPAN                NaN                  NaN
# 893    1765             CHINA                NaN                  NaN
# 817    1755           MOROCCO                NaN                  NaN
# ...
