# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_f = pd.read_csv('alcoholstudents.csv')

# %%
data_f.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data_f = data_f.drop(['Medu', 'Fedu', 'address', 'famsize', 'school', 'famrel', 'Dalc', 'Walc', 'G1', 'G2', 'G3', 'Pstatus', 'Mjob', 'Fjob'], axis=1)

# %%
data_f.head()
# Out:
#   sex  age  reason guardian  traveltime  studytime  failures schoolsup famsup  \
# 0   F   18  course   mother           2          2         0       yes     no
# 1   F   17  course   father           1          2         0        no    yes
# 2   F   15   other   mother           1          2         3       yes     no
# 3   F   15    home   mother           1          3         0        no    yes
# 4   F   16    home   father           1          2         0        no    yes
#
#   paid activities nursery higher internet romantic  freetime  goout  health  \
# 0   no         no     yes    yes       no       no         3      4       3
# 1   no         no      no    yes      yes       no         3      3       3
# 2  yes         no     yes    yes      yes       no         3      2       3
# 3  yes        yes     yes    yes      yes      yes         2      2       5
# 4  yes         no     yes    yes       no       no         3      2       5
#
#    absences
# 0         6
# 1         4
# ...

# %%
data_f['absences'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
data_f['guardian'].value_counts()
# Out:
# mother    273
# father     90
# other      32
# Name: guardian, dtype: int64
